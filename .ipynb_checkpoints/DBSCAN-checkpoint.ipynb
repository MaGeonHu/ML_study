# %% [markdown]
# ##### sklearn.cluster.dbscan
# * sklearn.cluster.dbscan(X, eps=0.5, *, min_samples=5, metric='minkowski', metric_params=None, algorithm='auto', leaf_size=30, p=2, sample_weight=None, n_jobs=None)

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
Xmoon, ymoon = make_moons(200,noise=.05,random_state=0)
plt.scatter(Xmoon[:,0], Xmoon[:,1])

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps = 0.2)
labels = dbscan.fit_predict(Xmoon)

# %%
from matplotlib.patches import Ellipse

def plot_dbscan(X, c = labels, label=True, ax=None):
    ax = ax or plt.gca()
    if label:
        ax.scatter(X[:, 0], X[:, 1], c=c, s=40, cmap='viridis', zorder=2)
    else:
        ax.scatter(X[:, 0], X[:, 1], s=40, zorder=2)
    ax.axis('equal')

# %%
plot_dbscan(Xmoon,labels)
